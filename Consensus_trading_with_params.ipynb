# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# Data Loading and Cleaning
def load_and_clean_data(file_path):
    df = pd.read_csv(file_path)
    
    # Clean column names
    df.columns = df.columns.str.strip().str.replace('\n', '')
    
    # keep both buys and sells (not just buys)
    # df = df[df.transaction_type.isin(['Buy', 'Sell'])]
    
    # Convert date columns to datetime
    date_cols = ['DATE OF ALLOTMENT/ACQUISITION FROM', 'DATE OF ALLOTMENT/ACQUISITION TO']
    for col in date_cols:
        df[col] = pd.to_datetime(df[col], format='%d-%b-%Y', errors='coerce')
    
    # Clean numeric columns
    df['NO. OF SECURITIES (ACQUIRED/DISPLOSED)'] = pd.to_numeric(
        df['NO. OF SECURITIES (ACQUIRED/DISPLOSED)'], errors='coerce'
    )
    
    # Clean VALUE column
    df['VALUE OF SECURITY (ACQUIRED/DISPLOSED)'] = df['VALUE OF SECURITY (ACQUIRED/DISPLOSED)'].replace('-', np.nan)
    df['VALUE OF SECURITY (ACQUIRED/DISPLOSED)'] = pd.to_numeric(
        df['VALUE OF SECURITY (ACQUIRED/DISPLOSED)'], errors='coerce'
    )
    
    return df

def filter_relevant_data(df):
    # Filter out rows with missing critical information
    df_filtered = df.dropna(subset=[
        'SYMBOL', 'DATE OF ALLOTMENT/ACQUISITION FROM', 
        'NO. OF SECURITIES (ACQUIRED/DISPLOSED)',
        'ACQUISITION/DISPOSAL TRANSACTION TYPE'
    ])
    
    # Filter for only Buy and Sell transactions
    df_filtered = df_filtered[df_filtered['ACQUISITION/DISPOSAL TRANSACTION TYPE'].isin(['Buy', 'Sell'])]
    
    # Filter for market transactions only
    market_modes = ['Market Sale', 'Market Purchase', 'Off Market']
    df_filtered = df_filtered[df_filtered['MODE OF ACQUISITION'].isin(market_modes)]
    
    # Filter for significant insider categories
    significant_categories = ['Promoters', 'Promoter Group', 'Director', 'Key Managerial Personnel']
    df_filtered = df_filtered[df_filtered['CATEGORY OF PERSON'].isin(significant_categories)]
    
    # Create transaction_type column (1 for Buy, -1 for Sell)
    df_filtered['transaction_type'] = df_filtered['ACQUISITION/DISPOSAL TRANSACTION TYPE'].map({
        'Buy': 1, 'Sell': -1
    })
    
    # Filter for reasonable date range (2022-2025)
    start_date = pd.to_datetime('2022-01-01')
    end_date = pd.to_datetime('2025-12-31')
    df_filtered = df_filtered[
        (df_filtered['DATE OF ALLOTMENT/ACQUISITION FROM'] >= start_date) & 
        (df_filtered['DATE OF ALLOTMENT/ACQUISITION FROM'] <= end_date)
    ]
    
    return df_filtered

# Feature Engineering
def create_insider_weights():
    
    return {
        'Promoters': 4,
        'Promoter Group': 3,
        'Director': 2,
        'Key Managerial Personnel': 1
    }

def add_insider_weights(df):
    weights = create_insider_weights()
    df['insider_weight'] = df['CATEGORY OF PERSON'].map(weights)
    return df

def calculate_transaction_metrics(df):
    # Calculate transaction value (if available)
    df['transaction_value'] = df['VALUE OF SECURITY (ACQUIRED/DISPLOSED)'].fillna(0)
    
    # Calculate weighted transaction score
    df['weighted_score'] = df['transaction_type'] * df['insider_weight'] * np.log1p(df['NO. OF SECURITIES (ACQUIRED/DISPLOSED)'])
    
    # Add transaction date as reference
    df['transaction_date'] = df['DATE OF ALLOTMENT/ACQUISITION FROM']
    
    return df

# Consensus Signal Generation
class ConsensusParameters:
    def __init__(self, lookback_window=3, min_insiders=3, min_net_score=2.0, 
                 signal_hold_period=30, min_transaction_value=1000000):
        self.lookback_window = lookback_window  # days
        self.min_insiders = min_insiders        # minimum number of insiders needed
        self.min_net_score = min_net_score      # minimum weighted net score
        self.signal_hold_period = signal_hold_period  # days to hold signal
        self.min_transaction_value = min_transaction_value  # minimum transaction value

def generate_consensus_signals(df, params):
    signals = []
    
    # Group by company symbol
    for symbol in df['SYMBOL'].unique():
        company_data = df[df['SYMBOL'] == symbol].copy()
        company_data = company_data.sort_values('transaction_date')
        
        # Create rolling window analysis
        signals.extend(analyze_company_consensus(company_data, params))
    
    signals_df = pd.DataFrame(signals)
    # Ensure signal_date is datetime and drop invalid
    signals_df['signal_date'] = pd.to_datetime(signals_df['signal_date'], errors='coerce')
    signals_df = signals_df.dropna(subset=['signal_date'])
    return signals_df

def analyze_company_consensus(company_data, params):
    signals = []
    
    # Ensure transaction_date is datetime
    company_data['transaction_date'] = pd.to_datetime(company_data['transaction_date'], errors='coerce')
    company_data = company_data.dropna(subset=['transaction_date'])
    
    # Get unique transaction dates
    transaction_dates = company_data['transaction_date'].unique()
    
    for date in transaction_dates:
        # Define lookback window
        window_start = date - timedelta(days=params.lookback_window)
        window_end = date
        
        # Filter data within window
        window_data = company_data[
            (company_data['transaction_date'] >= window_start) & 
            (company_data['transaction_date'] <= window_end)
        ]
        
        # Calculate consensus metrics
        signal = calculate_consensus_signal(window_data, date, params)
        if signal:
            signals.append(signal)
    
    return signals

def calculate_consensus_signal(window_data, signal_date, params):
    if len(window_data) < params.min_insiders:
        return None
    
    # Count unique insiders
    unique_insiders = window_data['NAME OF THE ACQUIRER/DISPOSER'].nunique()
    if unique_insiders < params.min_insiders:
        return None
    
    # Calculate net weighted score
    net_score = window_data['weighted_score'].sum()
    
    # Calculate transaction direction consensus
    buy_score = window_data[window_data['transaction_type'] == 1]['weighted_score'].sum()
    sell_score = abs(window_data[window_data['transaction_type'] == -1]['weighted_score'].sum())
    
    # Determine signal direction
    if buy_score > sell_score and net_score > params.min_net_score:
        signal_direction = 'BUY'
    elif sell_score > buy_score and abs(net_score) > params.min_net_score:
        signal_direction = 'SELL'
    else:
        return None
    
    # Calculate signal strength
    signal_strength = abs(net_score) / params.min_net_score
    
    return {
        'symbol': window_data['SYMBOL'].iloc[0],
        'company': window_data['COMPANY'].iloc[0],
        'signal_date': signal_date,
        'signal_direction': signal_direction,
        'signal_strength': signal_strength,
        'net_score': net_score,
        'unique_insiders': unique_insiders,
        'total_transactions': len(window_data),
        'buy_score': buy_score,
        'sell_score': sell_score
    }

# Signal Validation and Filtering
def filter_overlapping_signals(signals_df, params):
    filtered_signals = []
    
    for symbol in signals_df['symbol'].unique():
        company_signals = signals_df[signals_df['symbol'] == symbol].copy()
        company_signals = company_signals.sort_values('signal_date')
        
        last_signal_date = None
        for _, signal in company_signals.iterrows():
            if last_signal_date is None or (signal['signal_date'] - last_signal_date).days > params.signal_hold_period:
                filtered_signals.append(signal)
                last_signal_date = signal['signal_date']
    
    return pd.DataFrame(filtered_signals)

def add_quality_score(signals_df):
    # Normalize signal strength
    max_strength = signals_df['signal_strength'].max()
    signals_df['normalized_strength'] = signals_df['signal_strength'] / max_strength
    
    # Calculate quality score based on multiple factors
    signals_df['quality_score'] = (
        0.4 * signals_df['normalized_strength'] +
        0.3 * (signals_df['unique_insiders'] / signals_df['unique_insiders'].max()) +
        0.3 * (signals_df['total_transactions'] / signals_df['total_transactions'].max())
    )
    
    return signals_df

# Portfolio Construction
def calculate_position_sizes(signals_df, total_capital=1000000):
    # Filter for high quality signals
    high_quality_signals = signals_df[signals_df['quality_score'] >= 0.6]
    
    # Calculate position sizes
    total_quality_score = high_quality_signals['quality_score'].sum()
    high_quality_signals['position_size'] = (
        high_quality_signals['quality_score'] / total_quality_score * total_capital
    )
    
    return high_quality_signals

def apply_diversification_rules(portfolio_df, max_position_pct=0.15):
    total_capital = portfolio_df['position_size'].sum()
    max_position_size = total_capital * max_position_pct
    
    # Cap individual positions
    portfolio_df['position_size'] = portfolio_df['position_size'].clip(upper=max_position_size)
    
    # Rebalance to maintain total capital
    scale_factor = total_capital / portfolio_df['position_size'].sum()
    portfolio_df['position_size'] *= scale_factor
    
    return portfolio_df

# Backtesting Framework
def load_price_data(symbols):
    # This would typically connect to a financial data provider
    # For demonstration, we'll create a placeholder
    price_data = {}
    for symbol in symbols:
        # Placeholder for actual price data loading
        price_data[symbol] = generate_mock_price_data(symbol)
    return price_data

def generate_mock_price_data(symbol):
    dates = pd.date_range('2022-01-01', '2025-07-15', freq='D')
    prices = 100 * np.cumprod(1 + np.random.normal(0, 0.02, len(dates)))
    return pd.DataFrame({'date': dates, 'price': prices})

def run_backtest(portfolio_df, price_data, params):
    results = []
    
    for _, position in portfolio_df.iterrows():
        symbol = position['symbol']
        entry_date = position['signal_date']
        exit_date = entry_date + timedelta(days=params.signal_hold_period)
        
        # Get price data for this symbol
        symbol_prices = price_data.get(symbol)
        if symbol_prices is None:
            continue
        
        # Calculate returns
        entry_price = get_price_on_date(symbol_prices, entry_date)
        exit_price = get_price_on_date(symbol_prices, exit_date)
        
        if entry_price and exit_price:
            if position['signal_direction'] == 'BUY':
                return_pct = (exit_price - entry_price) / entry_price
            else:  # SELL
                return_pct = (entry_price - exit_price) / entry_price
            
            results.append({
                'symbol': symbol,
                'entry_date': entry_date,
                'exit_date': exit_date,
                'entry_price': entry_price,
                'exit_price': exit_price,
                'return_pct': return_pct,
                'position_size': position['position_size'],
                'pnl': return_pct * position['position_size']
            })
    
    return pd.DataFrame(results)

def get_price_on_date(price_data, target_date):
    # … [earlier integer‐date handling omitted for brevity] …

    # Ensure target_date is a pd.Timestamp
    target_date = pd.to_datetime(target_date, errors='coerce')
    if pd.isna(target_date):
        return None

    # Sort and re‐index by date so .asof() compares Timestamps
    price_series = (
        price_data
        .sort_values('date')
        .set_index('date')['price']
    )
    
    # asof now works on the datetime index
    closest_price = price_series.asof(target_date)
    if pd.isna(closest_price):
        return None
    
    return closest_price


# Performance Analysis
def calculate_performance_metrics(backtest_results):
    if len(backtest_results) == 0:
        return {}
    
    returns = backtest_results['return_pct']
    pnl = backtest_results['pnl']
    
    metrics = {
        'total_trades': len(backtest_results),
        'total_return': pnl.sum(),
        'win_rate': (returns > 0).mean(),
        'avg_return': returns.mean(),
        'volatility': returns.std(),
        'sharpe_ratio': returns.mean() / returns.std() if returns.std() > 0 else 0,
        'max_drawdown': calculate_max_drawdown(pnl),
        'profit_factor': calculate_profit_factor(pnl),
        'avg_win': returns[returns > 0].mean() if (returns > 0).any() else 0,
        'avg_loss': returns[returns < 0].mean() if (returns < 0).any() else 0
    }
    
    return metrics

def calculate_max_drawdown(pnl_series):
    cumulative_pnl = pnl_series.cumsum()
    rolling_max = cumulative_pnl.expanding().max()
    drawdown = cumulative_pnl - rolling_max
    return drawdown.min()

def calculate_profit_factor(pnl_series):
    gross_profit = pnl_series[pnl_series > 0].sum()
    gross_loss = abs(pnl_series[pnl_series < 0].sum())
    return gross_profit / gross_loss if gross_loss > 0 else np.inf

# Main Strategy Class
class ConsensusInsiderStrategy:
    def __init__(self, params=None):
        self.params = params or ConsensusParameters()
        self.raw_data = None
        self.cleaned_data = None
        self.signals = None
        self.portfolio = None
        self.backtest_results = None
        self.performance_metrics = None
    
    def load_data(self, file_path):
        self.raw_data = load_and_clean_data(file_path)
        self.cleaned_data = self.preprocess_data()
        return self
    
    def preprocess_data(self):
        df = filter_relevant_data(self.raw_data)
        df = add_insider_weights(df)
        df = calculate_transaction_metrics(df)
        return df
    
    def generate_signals(self):
        self.signals = generate_consensus_signals(self.cleaned_data, self.params)
        self.signals = filter_overlapping_signals(self.signals, self.params)
        self.signals = add_quality_score(self.signals)
        return self
    
    def build_portfolio(self, total_capital=1000000):
        self.portfolio = calculate_position_sizes(self.signals, total_capital)
        self.portfolio = apply_diversification_rules(self.portfolio)
        return self
    
    def run_backtest(self, price_data=None):
        if price_data is None:
            symbols = self.portfolio['symbol'].unique()
            price_data = load_price_data(symbols)
        
        self.backtest_results = run_backtest(self.portfolio, price_data, self.params)
        self.performance_metrics = calculate_performance_metrics(self.backtest_results)
        return self
    
    def get_results(self):
        return {
            'signals': self.signals,
            'portfolio': self.portfolio,
            'backtest_results': self.backtest_results,
            'performance_metrics': self.performance_metrics
        }

# Parameter Sweep Function
def run_parameter_sweep(param_sets, file_path='CF-Insider-Trading-equities-14-07-2022-to-14-07-2025.csv', 
                        total_capital=1000000):
    
    sweep_results = {}
    
    for i, params_dict in enumerate(param_sets):
        # Create parameters object with custom values
        params = ConsensusParameters(**params_dict)
        
        # Initialize and run strategy
        strategy = ConsensusInsiderStrategy(params=params)
        strategy.load_data(file_path)
        strategy.generate_signals()
        strategy.build_portfolio(total_capital=total_capital)
        strategy.run_backtest()
        
        # Get and store results
        results = strategy.get_results()
        sweep_results[f'Set_{i+1}'] = {
            'parameters': params_dict,
            'performance_metrics': results['performance_metrics']
        }
        
        # Print summary for this set
        print(f"\nResults for Parameter Set {i+1}: {params_dict}")
        for metric, value in results['performance_metrics'].items():
            print(f"{metric}: {value:.4f}")
    
    return sweep_results

# %%
import itertools

lookback_windows       = [3, 7]
min_insiders_list      = [1, 2]
min_net_scores         = [0.02, 0.08, 0.16, 0.2]
signal_hold_periods    = [1, 5, 10]
min_transaction_values = [0, 1000, 50000]

all_combos = list(itertools.product(
    lookback_windows,
    min_insiders_list,
    min_net_scores,
    signal_hold_periods,
    min_transaction_values
))

param_sets = []
for (lw, mi, mns, shp, mtv) in all_combos[:]:
    param_sets.append({
        'lookback_window'      : lw,
        'min_insiders'         : mi,
        'min_net_score'        : mns,
        'signal_hold_period'   : shp,
        'min_transaction_value': mtv
    })

for i, ps in enumerate(param_sets, 1):
    print(f"Set {i:2d}:", ps)

sweep_results = run_parameter_sweep(param_sets)
# Out:
# Set  1: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set  2: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set  3: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set  4: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set  5: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set  6: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set  7: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set  8: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set  9: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 10: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 11: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 12: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 13: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 14: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 15: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 16: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 17: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 18: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 19: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 20: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 21: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 22: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 23: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 24: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 25: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 26: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 27: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 28: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 29: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 30: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 31: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 32: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 33: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 34: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 35: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 36: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 37: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 38: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 39: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 40: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 41: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 42: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 43: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 44: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 45: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 46: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 47: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 48: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 49: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 50: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 51: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 52: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 53: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 54: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 55: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 56: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 57: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 58: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 59: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 60: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 61: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 62: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 63: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 64: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 65: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 66: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 67: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 68: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 69: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 70: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 71: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 72: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 73: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 74: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 75: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 76: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 77: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 78: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 79: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 80: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 81: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 82: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 83: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 84: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 85: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 86: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 87: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 88: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 89: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 90: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 91: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 92: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 93: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 94: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 95: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 96: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 97: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 98: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 99: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 100: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 101: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 102: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 103: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 104: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 105: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 106: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 107: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 108: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 109: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 110: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 111: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 112: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 113: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 114: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 115: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 116: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 117: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 118: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 119: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 120: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 121: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 122: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 123: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 124: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 125: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 126: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 127: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 128: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 129: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 130: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 131: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 132: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 133: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 134: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 135: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# Set 136: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 0}
# Set 137: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# Set 138: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# Set 139: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 0}
# Set 140: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# Set 141: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# Set 142: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 0}
# Set 143: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# Set 144: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 50000}
#
# Results for Parameter Set 1: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 9.0000
# total_return: 3662.4765
# win_rate: 0.5556
# avg_return: 0.0031
# volatility: 0.0188
# sharpe_ratio: 0.1674
# max_drawdown: -2671.4803
# profit_factor: 1.6617
# avg_win: 0.0158
# avg_loss: -0.0127
#
# Results for Parameter Set 2: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 9.0000
# total_return: -3924.1278
# win_rate: 0.4444
# avg_return: -0.0040
# volatility: 0.0220
# sharpe_ratio: -0.1834
# max_drawdown: -10461.4683
# profit_factor: 0.6249
# avg_win: 0.0140
# avg_loss: -0.0185
#
# Results for Parameter Set 3: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 9.0000
# total_return: -12233.7772
# win_rate: 0.3333
# avg_return: -0.0110
# volatility: 0.0232
# sharpe_ratio: -0.4765
# max_drawdown: -10951.0777
# profit_factor: 0.2888
# avg_win: 0.0158
# avg_loss: -0.0245
#
# Results for Parameter Set 4: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -6219.7179
# win_rate: 0.4000
# avg_return: -0.0062
# volatility: 0.0314
# sharpe_ratio: -0.1979
# max_drawdown: -11161.4087
# profit_factor: 0.5436
# avg_win: 0.0185
# avg_loss: -0.0227
#
# Results for Parameter Set 5: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 721.7559
# win_rate: 0.6000
# avg_return: 0.0007
# volatility: 0.0619
# sharpe_ratio: 0.0117
# max_drawdown: -18251.6623
# profit_factor: 1.0327
# avg_win: 0.0380
# avg_loss: -0.0553
#
# Results for Parameter Set 6: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -11149.9400
# win_rate: 0.4000
# avg_return: -0.0111
# volatility: 0.0632
# sharpe_ratio: -0.1765
# max_drawdown: -16346.8076
# profit_factor: 0.6234
# avg_win: 0.0461
# avg_loss: -0.0493
#
# Results for Parameter Set 7: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -41985.3155
# win_rate: 0.0000
# avg_return: -0.0420
# volatility: 0.0474
# sharpe_ratio: -0.8857
# max_drawdown: -37683.7968
# profit_factor: 0.0000
# avg_win: 0.0000
# avg_loss: -0.0420
#
# Results for Parameter Set 8: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: -11883.5988
# win_rate: 0.4000
# avg_return: -0.0119
# volatility: 0.0910
# sharpe_ratio: -0.1305
# max_drawdown: -33508.5818
# profit_factor: 0.7462
# avg_win: 0.0874
# avg_loss: -0.0780
#
# Results for Parameter Set 9: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -2361.7158
# win_rate: 0.6000
# avg_return: -0.0024
# volatility: 0.0292
# sharpe_ratio: -0.0809
# max_drawdown: -4902.9137
# profit_factor: 0.8040
# avg_win: 0.0161
# avg_loss: -0.0301
#
# Results for Parameter Set 10: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 9.0000
# total_return: 5883.7937
# win_rate: 0.6667
# avg_return: 0.0054
# volatility: 0.0175
# sharpe_ratio: 0.3080
# max_drawdown: -4158.6111
# profit_factor: 2.4148
# avg_win: 0.0148
# avg_loss: -0.0135
#
# Results for Parameter Set 11: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 9.0000
# total_return: 5379.8857
# win_rate: 0.5556
# avg_return: 0.0059
# volatility: 0.0147
# sharpe_ratio: 0.3987
# max_drawdown: -2334.6331
# profit_factor: 2.5075
# avg_win: 0.0167
# avg_loss: -0.0077
#
# Results for Parameter Set 12: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 9.0000
# total_return: -4643.5313
# win_rate: 0.4444
# avg_return: -0.0048
# volatility: 0.0286
# sharpe_ratio: -0.1682
# max_drawdown: -9791.5516
# profit_factor: 0.6563
# avg_win: 0.0199
# avg_loss: -0.0246
#
# Results for Parameter Set 13: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: 5918.6922
# win_rate: 0.8000
# avg_return: 0.0059
# volatility: 0.0288
# sharpe_ratio: 0.2054
# max_drawdown: 0.0000
# profit_factor: 1.7984
# avg_win: 0.0167
# avg_loss: -0.0371
#
# Results for Parameter Set 14: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 6628.1609
# win_rate: 0.6000
# avg_return: 0.0066
# volatility: 0.0522
# sharpe_ratio: 0.1269
# max_drawdown: -18549.8034
# profit_factor: 1.3573
# avg_win: 0.0420
# avg_loss: -0.0464
#
# Results for Parameter Set 15: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -9403.2629
# win_rate: 0.4000
# avg_return: -0.0094
# volatility: 0.0325
# sharpe_ratio: -0.2894
# max_drawdown: -16230.7267
# profit_factor: 0.4207
# avg_win: 0.0171
# avg_loss: -0.0271
#
# Results for Parameter Set 16: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: 15678.2972
# win_rate: 0.8000
# avg_return: 0.0157
# volatility: 0.0718
# sharpe_ratio: 0.2184
# max_drawdown: -19109.5636
# profit_factor: 1.8204
# avg_win: 0.0435
# avg_loss: -0.0955
#
# Results for Parameter Set 17: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: -15260.5149
# win_rate: 0.4000
# avg_return: -0.0153
# volatility: 0.0382
# sharpe_ratio: -0.4000
# max_drawdown: -17215.1247
# profit_factor: 0.3291
# avg_win: 0.0187
# avg_loss: -0.0379
#
# Results for Parameter Set 18: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: 15341.1172
# win_rate: 0.4000
# avg_return: 0.0153
# volatility: 0.0861
# sharpe_ratio: 0.1782
# max_drawdown: -15461.1018
# profit_factor: 1.6620
# avg_win: 0.0963
# avg_loss: -0.0386
#
# Results for Parameter Set 19: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 9.0000
# total_return: -1389.2904
# win_rate: 0.4444
# avg_return: -0.0007
# volatility: 0.0205
# sharpe_ratio: -0.0353
# max_drawdown: -3143.8271
# profit_factor: 0.8273
# avg_win: 0.0167
# avg_loss: -0.0147
#
# Results for Parameter Set 20: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 9.0000
# total_return: -5363.4922
# win_rate: 0.3333
# avg_return: -0.0058
# volatility: 0.0109
# sharpe_ratio: -0.5328
# max_drawdown: -6433.6024
# profit_factor: 0.2679
# avg_win: 0.0057
# avg_loss: -0.0116
#
# Results for Parameter Set 21: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 9.0000
# total_return: -393.6571
# win_rate: 0.5556
# avg_return: 0.0008
# volatility: 0.0176
# sharpe_ratio: 0.0473
# max_drawdown: -3205.3266
# profit_factor: 0.9445
# avg_win: 0.0131
# avg_loss: -0.0145
#
# Results for Parameter Set 22: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: 6020.7804
# win_rate: 0.8000
# avg_return: 0.0060
# volatility: 0.0381
# sharpe_ratio: 0.1581
# max_drawdown: -11098.0154
# profit_factor: 1.5425
# avg_win: 0.0214
# avg_loss: -0.0555
#
# Results for Parameter Set 23: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: -3787.6072
# win_rate: 0.6000
# avg_return: -0.0038
# volatility: 0.0141
# sharpe_ratio: -0.2689
# max_drawdown: -7257.6873
# profit_factor: 0.4781
# avg_win: 0.0058
# avg_loss: -0.0181
#
# Results for Parameter Set 24: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: 32215.2795
# win_rate: 1.0000
# avg_return: 0.0322
# volatility: 0.0133
# sharpe_ratio: 2.4209
# max_drawdown: 0.0000
# profit_factor: inf
# avg_win: 0.0322
# avg_loss: 0.0000
#
# Results for Parameter Set 25: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: 14516.9633
# win_rate: 0.6000
# avg_return: 0.0145
# volatility: 0.0511
# sharpe_ratio: 0.2842
# max_drawdown: -13263.7255
# profit_factor: 2.0225
# avg_win: 0.0479
# avg_loss: -0.0355
#
# Results for Parameter Set 26: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 1313.7330
# win_rate: 0.6000
# avg_return: 0.0013
# volatility: 0.0646
# sharpe_ratio: 0.0203
# max_drawdown: -23832.5429
# profit_factor: 1.0551
# avg_win: 0.0419
# avg_loss: -0.0596
#
# Results for Parameter Set 27: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: 9644.5185
# win_rate: 0.4000
# avg_return: 0.0096
# volatility: 0.0717
# sharpe_ratio: 0.1346
# max_drawdown: -10253.4586
# profit_factor: 1.4047
# avg_win: 0.0837
# avg_loss: -0.0397
#
# Results for Parameter Set 28: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 9.0000
# total_return: -6519.7284
# win_rate: 0.3333
# avg_return: -0.0066
# volatility: 0.0263
# sharpe_ratio: -0.2506
# max_drawdown: -4577.7343
# profit_factor: 0.5556
# avg_win: 0.0238
# avg_loss: -0.0218
#
# Results for Parameter Set 29: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 9.0000
# total_return: 3401.2350
# win_rate: 0.8889
# avg_return: 0.0028
# volatility: 0.0197
# sharpe_ratio: 0.1415
# max_drawdown: -4666.0343
# profit_factor: 1.7289
# avg_win: 0.0092
# avg_loss: -0.0487
#
# Results for Parameter Set 30: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 9.0000
# total_return: 3742.1265
# win_rate: 0.6667
# avg_return: 0.0024
# volatility: 0.0169
# sharpe_ratio: 0.1417
# max_drawdown: -3569.2082
# profit_factor: 1.7039
# avg_win: 0.0124
# avg_loss: -0.0175
#
# Results for Parameter Set 31: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -5205.9525
# win_rate: 0.4000
# avg_return: -0.0052
# volatility: 0.0411
# sharpe_ratio: -0.1268
# max_drawdown: -17675.8230
# profit_factor: 0.7055
# avg_win: 0.0312
# avg_loss: -0.0295
#
# Results for Parameter Set 32: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 3657.3470
# win_rate: 0.8000
# avg_return: 0.0037
# volatility: 0.0348
# sharpe_ratio: 0.1052
# max_drawdown: 0.0000
# profit_factor: 1.3493
# avg_win: 0.0177
# avg_loss: -0.0524
#
# Results for Parameter Set 33: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -31064.8753
# win_rate: 0.4000
# avg_return: -0.0311
# volatility: 0.0383
# sharpe_ratio: -0.8115
# max_drawdown: -32981.2207
# profit_factor: 0.0908
# avg_win: 0.0078
# avg_loss: -0.0569
#
# Results for Parameter Set 34: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -13002.7666
# win_rate: 0.2000
# avg_return: -0.0130
# volatility: 0.0547
# sharpe_ratio: -0.2375
# max_drawdown: -24617.0843
# profit_factor: 0.5183
# avg_win: 0.0700
# avg_loss: -0.0337
#
# Results for Parameter Set 35: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: -8185.4031
# win_rate: 0.4000
# avg_return: -0.0082
# volatility: 0.0524
# sharpe_ratio: -0.1562
# max_drawdown: -6092.2100
# profit_factor: 0.6576
# avg_win: 0.0393
# avg_loss: -0.0398
#
# Results for Parameter Set 36: {'lookback_window': 3, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -54029.5605
# win_rate: 0.2000
# avg_return: -0.0540
# volatility: 0.0712
# sharpe_ratio: -0.7583
# max_drawdown: -49187.7256
# profit_factor: 0.1044
# avg_win: 0.0315
# avg_loss: -0.0754
#
# Results for Parameter Set 37: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 8.0000
# total_return: -1764.3811
# win_rate: 0.2500
# avg_return: -0.0021
# volatility: 0.0144
# sharpe_ratio: -0.1453
# max_drawdown: -3584.1417
# profit_factor: 0.7160
# avg_win: 0.0173
# avg_loss: -0.0085
#
# Results for Parameter Set 38: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 8.0000
# total_return: -3479.1839
# win_rate: 0.5000
# avg_return: -0.0039
# volatility: 0.0220
# sharpe_ratio: -0.1758
# max_drawdown: -5998.4730
# profit_factor: 0.5841
# avg_win: 0.0101
# avg_loss: -0.0178
#
# Results for Parameter Set 39: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 8.0000
# total_return: -5389.3795
# win_rate: 0.3750
# avg_return: -0.0047
# volatility: 0.0176
# sharpe_ratio: -0.2673
# max_drawdown: -6503.0128
# profit_factor: 0.4729
# avg_win: 0.0142
# avg_loss: -0.0160
#
# Results for Parameter Set 40: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: 25416.0149
# win_rate: 0.6000
# avg_return: 0.0254
# volatility: 0.0475
# sharpe_ratio: 0.5347
# max_drawdown: -7239.5174
# profit_factor: 4.5107
# avg_win: 0.0544
# avg_loss: -0.0181
#
# Results for Parameter Set 41: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 3355.3755
# win_rate: 0.6000
# avg_return: 0.0034
# volatility: 0.0342
# sharpe_ratio: 0.0981
# max_drawdown: -7629.5117
# profit_factor: 1.2830
# avg_win: 0.0254
# avg_loss: -0.0296
#
# Results for Parameter Set 42: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -42762.5474
# win_rate: 0.0000
# avg_return: -0.0428
# volatility: 0.0450
# sharpe_ratio: -0.9493
# max_drawdown: -32546.5118
# profit_factor: 0.0000
# avg_win: 0.0000
# avg_loss: -0.0428
#
# Results for Parameter Set 43: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -20474.6769
# win_rate: 0.2000
# avg_return: -0.0205
# volatility: 0.0532
# sharpe_ratio: -0.3849
# max_drawdown: -34812.4511
# profit_factor: 0.4119
# avg_win: 0.0717
# avg_loss: -0.0435
#
# Results for Parameter Set 44: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 6153.6229
# win_rate: 0.4000
# avg_return: 0.0062
# volatility: 0.0422
# sharpe_ratio: 0.1459
# max_drawdown: -11341.5574
# profit_factor: 1.4522
# avg_win: 0.0494
# avg_loss: -0.0227
#
# Results for Parameter Set 45: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: 11331.7983
# win_rate: 0.8000
# avg_return: 0.0113
# volatility: 0.0168
# sharpe_ratio: 0.6731
# max_drawdown: -1633.1974
# profit_factor: 7.9384
# avg_win: 0.0162
# avg_loss: -0.0082
#
# Results for Parameter Set 46: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 8.0000
# total_return: 2518.1486
# win_rate: 0.5000
# avg_return: 0.0022
# volatility: 0.0167
# sharpe_ratio: 0.1344
# max_drawdown: -2700.3827
# profit_factor: 1.4701
# avg_win: 0.0157
# avg_loss: -0.0112
#
# Results for Parameter Set 47: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 8.0000
# total_return: 10.2517
# win_rate: 0.5000
# avg_return: 0.0002
# volatility: 0.0273
# sharpe_ratio: 0.0090
# max_drawdown: -3104.5483
# profit_factor: 1.0010
# avg_win: 0.0215
# avg_loss: -0.0210
#
# Results for Parameter Set 48: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 8.0000
# total_return: 4202.0543
# win_rate: 0.3750
# avg_return: 0.0035
# volatility: 0.0349
# sharpe_ratio: 0.0995
# max_drawdown: -5718.9291
# profit_factor: 1.4462
# avg_win: 0.0353
# avg_loss: -0.0156
#
# Results for Parameter Set 49: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: 5090.2883
# win_rate: 0.4000
# avg_return: 0.0051
# volatility: 0.0575
# sharpe_ratio: 0.0885
# max_drawdown: -13591.7345
# profit_factor: 1.2874
# avg_win: 0.0570
# avg_loss: -0.0295
#
# Results for Parameter Set 50: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: -8764.5944
# win_rate: 0.4000
# avg_return: -0.0088
# volatility: 0.0470
# sharpe_ratio: -0.1865
# max_drawdown: -14515.9973
# profit_factor: 0.6204
# avg_win: 0.0358
# avg_loss: -0.0385
#
# Results for Parameter Set 51: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: 14024.4110
# win_rate: 0.6000
# avg_return: 0.0140
# volatility: 0.0278
# sharpe_ratio: 0.5047
# max_drawdown: -4291.9219
# profit_factor: 4.0249
# avg_win: 0.0311
# avg_loss: -0.0116
#
# Results for Parameter Set 52: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: 55884.0893
# win_rate: 0.8000
# avg_return: 0.0559
# volatility: 0.0423
# sharpe_ratio: 1.3205
# max_drawdown: -284.9033
# profit_factor: 197.1511
# avg_win: 0.0702
# avg_loss: -0.0014
#
# Results for Parameter Set 53: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 22096.8520
# win_rate: 0.6000
# avg_return: 0.0221
# volatility: 0.0552
# sharpe_ratio: 0.4002
# max_drawdown: -12738.6747
# profit_factor: 2.7346
# avg_win: 0.0581
# avg_loss: -0.0318
#
# Results for Parameter Set 54: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: 14748.2593
# win_rate: 0.4000
# avg_return: 0.0147
# volatility: 0.0527
# sharpe_ratio: 0.2799
# max_drawdown: -11020.6105
# profit_factor: 2.0462
# avg_win: 0.0721
# avg_loss: -0.0235
#
# Results for Parameter Set 55: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 8.0000
# total_return: 2792.7362
# win_rate: 0.5000
# avg_return: 0.0029
# volatility: 0.0154
# sharpe_ratio: 0.1893
# max_drawdown: -2055.9977
# profit_factor: 1.5751
# avg_win: 0.0160
# avg_loss: -0.0102
#
# Results for Parameter Set 56: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 8.0000
# total_return: 15098.8752
# win_rate: 0.7500
# avg_return: 0.0147
# volatility: 0.0185
# sharpe_ratio: 0.7975
# max_drawdown: -1282.1465
# profit_factor: 6.9131
# avg_win: 0.0234
# avg_loss: -0.0113
#
# Results for Parameter Set 57: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 8.0000
# total_return: -870.8245
# win_rate: 0.5000
# avg_return: -0.0012
# volatility: 0.0177
# sharpe_ratio: -0.0699
# max_drawdown: -5525.7539
# profit_factor: 0.8850
# avg_win: 0.0129
# avg_loss: -0.0154
#
# Results for Parameter Set 58: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -20752.1083
# win_rate: 0.0000
# avg_return: -0.0208
# volatility: 0.0168
# sharpe_ratio: -1.2326
# max_drawdown: -19448.4089
# profit_factor: 0.0000
# avg_win: 0.0000
# avg_loss: -0.0208
#
# Results for Parameter Set 59: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 27456.8321
# win_rate: 0.6000
# avg_return: 0.0275
# volatility: 0.0339
# sharpe_ratio: 0.8111
# max_drawdown: -3394.8521
# profit_factor: 9.0878
# avg_win: 0.0514
# avg_loss: -0.0085
#
# Results for Parameter Set 60: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: 36945.5797
# win_rate: 0.8000
# avg_return: 0.0369
# volatility: 0.0492
# sharpe_ratio: 0.7512
# max_drawdown: -2552.2501
# profit_factor: 15.4757
# avg_win: 0.0494
# avg_loss: -0.0128
#
# Results for Parameter Set 61: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: 28366.5911
# win_rate: 0.4000
# avg_return: 0.0284
# volatility: 0.0820
# sharpe_ratio: 0.3460
# max_drawdown: -13729.4555
# profit_factor: 2.7723
# avg_win: 0.1109
# avg_loss: -0.0267
#
# Results for Parameter Set 62: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 22458.6759
# win_rate: 0.8000
# avg_return: 0.0225
# volatility: 0.0299
# sharpe_ratio: 0.7514
# max_drawdown: -3788.0075
# profit_factor: 6.9289
# avg_win: 0.0328
# avg_loss: -0.0189
#
# Results for Parameter Set 63: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -19260.6737
# win_rate: 0.2000
# avg_return: -0.0193
# volatility: 0.0674
# sharpe_ratio: -0.2858
# max_drawdown: -36596.7671
# profit_factor: 0.4737
# avg_win: 0.0867
# avg_loss: -0.0457
#
# Results for Parameter Set 64: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 8.0000
# total_return: 8193.6209
# win_rate: 0.8750
# avg_return: 0.0088
# volatility: 0.0189
# sharpe_ratio: 0.4638
# max_drawdown: -4479.6638
# profit_factor: 2.8291
# avg_win: 0.0146
# avg_loss: -0.0323
#
# Results for Parameter Set 65: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 8.0000
# total_return: -512.5999
# win_rate: 0.6250
# avg_return: 0.0001
# volatility: 0.0158
# sharpe_ratio: 0.0080
# max_drawdown: -5332.8364
# profit_factor: 0.9195
# avg_win: 0.0100
# avg_loss: -0.0164
#
# Results for Parameter Set 66: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 8.0000
# total_return: 2376.5990
# win_rate: 0.6250
# avg_return: 0.0029
# volatility: 0.0153
# sharpe_ratio: 0.1875
# max_drawdown: -3009.3425
# profit_factor: 1.4598
# avg_win: 0.0123
# avg_loss: -0.0128
#
# Results for Parameter Set 67: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -36831.2263
# win_rate: 0.0000
# avg_return: -0.0368
# volatility: 0.0243
# sharpe_ratio: -1.5131
# max_drawdown: -32244.2999
# profit_factor: 0.0000
# avg_win: 0.0000
# avg_loss: -0.0368
#
# Results for Parameter Set 68: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 24850.9464
# win_rate: 1.0000
# avg_return: 0.0249
# volatility: 0.0109
# sharpe_ratio: 2.2883
# max_drawdown: 0.0000
# profit_factor: inf
# avg_win: 0.0249
# avg_loss: 0.0000
#
# Results for Parameter Set 69: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: 18906.3318
# win_rate: 0.6000
# avg_return: 0.0189
# volatility: 0.0274
# sharpe_ratio: 0.6894
# max_drawdown: -1353.3228
# profit_factor: 11.6173
# avg_win: 0.0345
# avg_loss: -0.0045
#
# Results for Parameter Set 70: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -2239.9743
# win_rate: 0.4000
# avg_return: -0.0022
# volatility: 0.0578
# sharpe_ratio: -0.0387
# max_drawdown: -7487.8721
# profit_factor: 0.8944
# avg_win: 0.0474
# avg_loss: -0.0354
#
# Results for Parameter Set 71: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 5869.6966
# win_rate: 0.6000
# avg_return: 0.0059
# volatility: 0.0356
# sharpe_ratio: 0.1650
# max_drawdown: -6521.2885
# profit_factor: 1.4906
# avg_win: 0.0297
# avg_loss: -0.0299
#
# Results for Parameter Set 72: {'lookback_window': 3, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -34913.4524
# win_rate: 0.2000
# avg_return: -0.0349
# volatility: 0.0269
# sharpe_ratio: -1.2994
# max_drawdown: -23252.9767
# profit_factor: 0.0034
# avg_win: 0.0006
# avg_loss: -0.0438
#
# Results for Parameter Set 73: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 7.0000
# total_return: -8397.2538
# win_rate: 0.4286
# avg_return: -0.0091
# volatility: 0.0198
# sharpe_ratio: -0.4624
# max_drawdown: -9504.4193
# profit_factor: 0.2110
# avg_win: 0.0050
# avg_loss: -0.0198
#
# Results for Parameter Set 74: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 7.0000
# total_return: 7127.6886
# win_rate: 0.8571
# avg_return: 0.0074
# volatility: 0.0223
# sharpe_ratio: 0.3313
# max_drawdown: -6062.2173
# profit_factor: 2.1758
# avg_win: 0.0153
# avg_loss: -0.0404
#
# Results for Parameter Set 75: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 7.0000
# total_return: -4081.5735
# win_rate: 0.5714
# avg_return: -0.0046
# volatility: 0.0173
# sharpe_ratio: -0.2686
# max_drawdown: -6307.9729
# profit_factor: 0.4624
# avg_win: 0.0061
# avg_loss: -0.0189
#
# Results for Parameter Set 76: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -17634.1590
# win_rate: 0.4000
# avg_return: -0.0176
# volatility: 0.0403
# sharpe_ratio: -0.4375
# max_drawdown: -10559.0651
# profit_factor: 0.3152
# avg_win: 0.0203
# avg_loss: -0.0429
#
# Results for Parameter Set 77: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: -13698.0075
# win_rate: 0.2000
# avg_return: -0.0137
# volatility: 0.0256
# sharpe_ratio: -0.5355
# max_drawdown: -10668.3582
# profit_factor: 0.2639
# avg_win: 0.0246
# avg_loss: -0.0233
#
# Results for Parameter Set 78: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -24714.3380
# win_rate: 0.2000
# avg_return: -0.0247
# volatility: 0.0383
# sharpe_ratio: -0.6450
# max_drawdown: -29778.9648
# profit_factor: 0.1898
# avg_win: 0.0289
# avg_loss: -0.0381
#
# Results for Parameter Set 79: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 7.0000
# total_return: 14959.0051
# win_rate: 0.8571
# avg_return: 0.0153
# volatility: 0.0446
# sharpe_ratio: 0.3437
# max_drawdown: -11686.9544
# profit_factor: 2.2800
# avg_win: 0.0312
# avg_loss: -0.0797
#
# Results for Parameter Set 80: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 7.0000
# total_return: 13047.1304
# win_rate: 0.7143
# avg_return: 0.0135
# volatility: 0.0629
# sharpe_ratio: 0.2147
# max_drawdown: -16985.0118
# profit_factor: 1.7445
# avg_win: 0.0420
# avg_loss: -0.0577
#
# Results for Parameter Set 81: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 7.0000
# total_return: 13146.1832
# win_rate: 0.5714
# avg_return: 0.0135
# volatility: 0.0604
# sharpe_ratio: 0.2241
# max_drawdown: -11801.5941
# profit_factor: 1.7150
# avg_win: 0.0562
# avg_loss: -0.0434
#
# Results for Parameter Set 82: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 7.0000
# total_return: -3976.5532
# win_rate: 0.4286
# avg_return: -0.0039
# volatility: 0.0161
# sharpe_ratio: -0.2407
# max_drawdown: -8556.5275
# profit_factor: 0.5386
# avg_win: 0.0109
# avg_loss: -0.0150
#
# Results for Parameter Set 83: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 7.0000
# total_return: -5753.2469
# win_rate: 0.1429
# avg_return: -0.0058
# volatility: 0.0054
# sharpe_ratio: -1.0764
# max_drawdown: -4284.7818
# profit_factor: 0.1165
# ...
# total_trades: 7.0000
# total_return: -4315.7800
# win_rate: 0.2857
# avg_return: -0.0040
# volatility: 0.0114
# sharpe_ratio: -0.3500
# max_drawdown: -4506.1777
# profit_factor: 0.3456
# avg_win: 0.0085
# avg_loss: -0.0090
#
# Results for Parameter Set 101: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 7.0000
# total_return: 10305.5435
# win_rate: 0.7143
# avg_return: 0.0104
# volatility: 0.0160
# sharpe_ratio: 0.6497
# max_drawdown: -1288.9141
# profit_factor: 8.9955
# avg_win: 0.0164
# avg_loss: -0.0046
#
# Results for Parameter Set 102: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 7.0000
# total_return: 5910.0392
# win_rate: 0.4286
# avg_return: 0.0065
# volatility: 0.0277
# sharpe_ratio: 0.2346
# max_drawdown: -3610.1816
# profit_factor: 1.8671
# avg_win: 0.0311
# avg_loss: -0.0120
#
# Results for Parameter Set 103: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -10726.3113
# win_rate: 0.2000
# avg_return: -0.0107
# volatility: 0.0152
# sharpe_ratio: -0.7047
# max_drawdown: -10976.0773
# profit_factor: 0.0228
# avg_win: 0.0012
# avg_loss: -0.0137
#
# Results for Parameter Set 104: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: -20268.9863
# win_rate: 0.2000
# avg_return: -0.0203
# volatility: 0.0377
# sharpe_ratio: -0.5378
# max_drawdown: -19619.4893
# profit_factor: 0.2397
# avg_win: 0.0319
# avg_loss: -0.0333
#
# Results for Parameter Set 105: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -10111.3208
# win_rate: 0.4000
# avg_return: -0.0101
# volatility: 0.0510
# sharpe_ratio: -0.1983
# max_drawdown: -15024.5882
# profit_factor: 0.6006
# avg_win: 0.0380
# avg_loss: -0.0422
#
# Results for Parameter Set 106: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 7.0000
# total_return: 6860.4722
# win_rate: 0.5714
# avg_return: 0.0084
# volatility: 0.0702
# sharpe_ratio: 0.1193
# max_drawdown: -6826.1783
# profit_factor: 1.2580
# avg_win: 0.0597
# avg_loss: -0.0600
#
# Results for Parameter Set 107: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 7.0000
# total_return: -20029.0520
# win_rate: 0.4286
# avg_return: -0.0201
# volatility: 0.0705
# sharpe_ratio: -0.2845
# max_drawdown: -36264.4095
# profit_factor: 0.4497
# avg_win: 0.0396
# avg_loss: -0.0648
#
# Results for Parameter Set 108: {'lookback_window': 7, 'min_insiders': 1, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 7.0000
# total_return: 15862.7463
# win_rate: 0.5714
# avg_return: 0.0160
# volatility: 0.0582
# sharpe_ratio: 0.2751
# max_drawdown: -11446.1518
# profit_factor: 1.8839
# avg_win: 0.0590
# avg_loss: -0.0414
#
# Results for Parameter Set 109: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 7.0000
# total_return: 15171.1603
# win_rate: 0.7143
# avg_return: 0.0150
# volatility: 0.0164
# sharpe_ratio: 0.9140
# max_drawdown: -888.5357
# profit_factor: 18.0743
# avg_win: 0.0223
# avg_loss: -0.0032
#
# Results for Parameter Set 110: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 7.0000
# total_return: 4247.6948
# win_rate: 0.8571
# avg_return: 0.0045
# volatility: 0.0090
# sharpe_ratio: 0.4952
# max_drawdown: 0.0000
# profit_factor: 3.1365
# avg_win: 0.0074
# avg_loss: -0.0135
#
# Results for Parameter Set 111: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 7.0000
# total_return: -6218.7313
# win_rate: 0.4286
# avg_return: -0.0059
# volatility: 0.0206
# sharpe_ratio: -0.2867
# max_drawdown: -8043.5995
# profit_factor: 0.4472
# avg_win: 0.0124
# avg_loss: -0.0196
#
# Results for Parameter Set 112: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: 17647.8950
# win_rate: 0.6000
# avg_return: 0.0176
# volatility: 0.0713
# sharpe_ratio: 0.2475
# max_drawdown: -21672.8465
# profit_factor: 1.8143
# avg_win: 0.0655
# avg_loss: -0.0542
#
# Results for Parameter Set 113: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 16006.1809
# win_rate: 0.6000
# avg_return: 0.0160
# volatility: 0.0185
# sharpe_ratio: 0.8635
# max_drawdown: -1300.7458
# profit_factor: 13.3054
# avg_win: 0.0288
# avg_loss: -0.0033
#
# Results for Parameter Set 114: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -9887.9782
# win_rate: 0.6000
# avg_return: -0.0099
# volatility: 0.0711
# sharpe_ratio: -0.1391
# max_drawdown: -7344.2797
# profit_factor: 0.6804
# avg_win: 0.0351
# avg_loss: -0.0773
#
# Results for Parameter Set 115: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -25135.4694
# win_rate: 0.4000
# avg_return: -0.0251
# volatility: 0.0405
# sharpe_ratio: -0.6211
# max_drawdown: -30076.0271
# profit_factor: 0.2093
# avg_win: 0.0166
# avg_loss: -0.0530
#
# Results for Parameter Set 116: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 17466.9456
# win_rate: 0.6000
# avg_return: 0.0175
# volatility: 0.0396
# sharpe_ratio: 0.4412
# max_drawdown: -1614.4594
# profit_factor: 3.5718
# avg_win: 0.0404
# avg_loss: -0.0170
#
# Results for Parameter Set 117: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.02, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -5571.4370
# win_rate: 0.4000
# avg_return: -0.0056
# volatility: 0.0529
# sharpe_ratio: -0.1053
# max_drawdown: -18105.7175
# profit_factor: 0.7184
# avg_win: 0.0355
# avg_loss: -0.0330
#
# Results for Parameter Set 118: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 7.0000
# total_return: 2704.3502
# win_rate: 0.5714
# avg_return: 0.0027
# volatility: 0.0155
# sharpe_ratio: 0.1767
# max_drawdown: -2699.3236
# profit_factor: 1.7149
# avg_win: 0.0113
# avg_loss: -0.0087
#
# Results for Parameter Set 119: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 7.0000
# total_return: -4233.4524
# win_rate: 0.2857
# avg_return: -0.0041
# volatility: 0.0095
# sharpe_ratio: -0.4277
# max_drawdown: -4032.9724
# profit_factor: 0.2276
# avg_win: 0.0043
# avg_loss: -0.0074
#
# Results for Parameter Set 120: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 7.0000
# total_return: 15473.4819
# win_rate: 0.7143
# avg_return: 0.0156
# volatility: 0.0157
# sharpe_ratio: 0.9951
# max_drawdown: -615.2803
# profit_factor: 18.5242
# avg_win: 0.0231
# avg_loss: -0.0031
#
# Results for Parameter Set 121: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -461.6739
# win_rate: 0.6000
# avg_return: -0.0005
# volatility: 0.0124
# sharpe_ratio: -0.0373
# max_drawdown: -2599.5062
# profit_factor: 0.9153
# avg_win: 0.0083
# avg_loss: -0.0136
#
# Results for Parameter Set 122: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: -49.8537
# win_rate: 0.6000
# avg_return: -0.0000
# volatility: 0.0509
# sharpe_ratio: -0.0010
# max_drawdown: -13218.6181
# profit_factor: 0.9977
# avg_win: 0.0355
# avg_loss: -0.0534
#
# Results for Parameter Set 123: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: 24742.4154
# win_rate: 0.8000
# avg_return: 0.0247
# volatility: 0.0325
# sharpe_ratio: 0.7606
# max_drawdown: 0.0000
# profit_factor: 8.9716
# avg_win: 0.0348
# avg_loss: -0.0155
#
# Results for Parameter Set 124: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -30279.4383
# win_rate: 0.2000
# avg_return: -0.0303
# volatility: 0.0653
# sharpe_ratio: -0.4637
# max_drawdown: -11769.8873
# profit_factor: 0.3088
# avg_win: 0.0676
# avg_loss: -0.0548
#
# Results for Parameter Set 125: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: -45277.3200
# win_rate: 0.2000
# avg_return: -0.0453
# volatility: 0.0388
# sharpe_ratio: -1.1674
# max_drawdown: -27802.9031
# profit_factor: 0.0277
# avg_win: 0.0064
# avg_loss: -0.0582
#
# Results for Parameter Set 126: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.08, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: 11826.2808
# win_rate: 0.6000
# avg_return: 0.0118
# volatility: 0.0463
# sharpe_ratio: 0.2555
# max_drawdown: -10174.0773
# profit_factor: 1.7963
# avg_win: 0.0445
# avg_loss: -0.0371
#
# Results for Parameter Set 127: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 7.0000
# total_return: -12196.5977
# win_rate: 0.2857
# avg_return: -0.0126
# volatility: 0.0165
# sharpe_ratio: -0.7637
# max_drawdown: -15445.8113
# profit_factor: 0.2104
# avg_win: 0.0110
# avg_loss: -0.0220
#
# Results for Parameter Set 128: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 7.0000
# total_return: -3618.2430
# win_rate: 0.4286
# avg_return: -0.0034
# volatility: 0.0302
# sharpe_ratio: -0.1134
# max_drawdown: -6766.4049
# profit_factor: 0.7274
# avg_win: 0.0231
# avg_loss: -0.0233
#
# Results for Parameter Set 129: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 7.0000
# total_return: 3773.3311
# win_rate: 0.7143
# avg_return: 0.0038
# volatility: 0.0132
# sharpe_ratio: 0.2885
# max_drawdown: -2058.0343
# profit_factor: 2.0068
# avg_win: 0.0107
# avg_loss: -0.0133
#
# Results for Parameter Set 130: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -10813.2197
# win_rate: 0.4000
# avg_return: -0.0108
# volatility: 0.0444
# sharpe_ratio: -0.2433
# max_drawdown: -18980.8859
# profit_factor: 0.5694
# avg_win: 0.0357
# avg_loss: -0.0418
#
# Results for Parameter Set 131: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: -23772.6699
# win_rate: 0.4000
# avg_return: -0.0238
# volatility: 0.0837
# sharpe_ratio: -0.2839
# max_drawdown: -19232.2148
# profit_factor: 0.4970
# avg_win: 0.0587
# avg_loss: -0.0788
#
# Results for Parameter Set 132: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -20823.3036
# win_rate: 0.4000
# avg_return: -0.0208
# volatility: 0.0494
# sharpe_ratio: -0.4214
# max_drawdown: -31100.8408
# profit_factor: 0.3452
# avg_win: 0.0274
# avg_loss: -0.0530
#
# Results for Parameter Set 133: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: 57949.1841
# win_rate: 1.0000
# avg_return: 0.0579
# volatility: 0.0288
# sharpe_ratio: 2.0087
# max_drawdown: 0.0000
# profit_factor: inf
# avg_win: 0.0579
# avg_loss: 0.0000
#
# Results for Parameter Set 134: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 34364.3158
# win_rate: 0.8000
# avg_return: 0.0344
# volatility: 0.0759
# sharpe_ratio: 0.4529
# max_drawdown: -13695.9078
# profit_factor: 3.5091
# avg_win: 0.0601
# avg_loss: -0.0685
#
# Results for Parameter Set 135: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.16, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: 589.0339
# win_rate: 0.4000
# avg_return: 0.0006
# volatility: 0.0538
# sharpe_ratio: 0.0109
# max_drawdown: -22041.3019
# profit_factor: 1.0267
# avg_win: 0.0566
# avg_loss: -0.0367
#
# Results for Parameter Set 136: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 0}
# total_trades: 7.0000
# total_return: 3004.1053
# win_rate: 0.5714
# avg_return: 0.0033
# volatility: 0.0170
# sharpe_ratio: 0.1917
# max_drawdown: -4220.1986
# profit_factor: 1.5043
# avg_win: 0.0159
# avg_loss: -0.0136
#
# Results for Parameter Set 137: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 1000}
# total_trades: 7.0000
# total_return: -10731.1899
# win_rate: 0.0000
# avg_return: -0.0109
# volatility: 0.0090
# sharpe_ratio: -1.2130
# max_drawdown: -9392.5168
# profit_factor: 0.0000
# avg_win: 0.0000
# avg_loss: -0.0109
#
# Results for Parameter Set 138: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 1, 'min_transaction_value': 50000}
# total_trades: 7.0000
# total_return: 4165.2784
# win_rate: 0.4286
# avg_return: 0.0036
# volatility: 0.0252
# sharpe_ratio: 0.1445
# max_drawdown: -5239.8013
# profit_factor: 1.4691
# avg_win: 0.0294
# avg_loss: -0.0157
#
# Results for Parameter Set 139: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: -27422.8482
# win_rate: 0.4000
# avg_return: -0.0274
# volatility: 0.0697
# sharpe_ratio: -0.3937
# max_drawdown: -21778.4454
# profit_factor: 0.3619
# avg_win: 0.0389
# avg_loss: -0.0716
#
# Results for Parameter Set 140: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 18469.8973
# win_rate: 0.6000
# avg_return: 0.0185
# volatility: 0.0437
# sharpe_ratio: 0.4228
# max_drawdown: -7538.3611
# profit_factor: 2.6749
# avg_win: 0.0492
# avg_loss: -0.0276
#
# Results for Parameter Set 141: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 5, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: -20314.3466
# win_rate: 0.2000
# avg_return: -0.0203
# volatility: 0.0396
# sharpe_ratio: -0.5125
# max_drawdown: -20861.7848
# profit_factor: 0.2984
# avg_win: 0.0432
# avg_loss: -0.0362
#
# Results for Parameter Set 142: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 0}
# total_trades: 5.0000
# total_return: 37380.8694
# win_rate: 0.8000
# avg_return: 0.0374
# volatility: 0.0372
# sharpe_ratio: 1.0035
# max_drawdown: 0.0000
# profit_factor: 11.2596
# avg_win: 0.0513
# avg_loss: -0.0182
#
# Results for Parameter Set 143: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 1000}
# total_trades: 5.0000
# total_return: 7363.0292
# win_rate: 0.6000
# avg_return: 0.0074
# volatility: 0.0548
# sharpe_ratio: 0.1344
# max_drawdown: -12864.5466
# profit_factor: 1.4299
# avg_win: 0.0408
# avg_loss: -0.0428
#
# Results for Parameter Set 144: {'lookback_window': 7, 'min_insiders': 2, 'min_net_score': 0.2, 'signal_hold_period': 10, 'min_transaction_value': 50000}
# total_trades: 5.0000
# total_return: 13763.4947
# win_rate: 0.6000
# avg_return: 0.0138
# volatility: 0.0242
# sharpe_ratio: 0.5690
# max_drawdown: -3510.3217
# profit_factor: 3.8880
# avg_win: 0.0309
# avg_loss: -0.0119

# %%
import pandas as pd

try:
    from tabulate import tabulate

    def pretty_print(df: pd.DataFrame, title: str):
        print(f"\n=== {title} ===")
        print(tabulate(df, headers='keys', tablefmt='psql', floatfmt=".4f"))
except ImportError:
    def pretty_print(df: pd.DataFrame, title: str):
        print(f"\n=== {title} ===")
        print(df.to_string(float_format=lambda x: f"{x:,.4f}"))

def rank_strategies(sweep_results, total_capital=1000000):
    records = []
    for name, res in sweep_results.items():
        m = res['performance_metrics']
        records.append({'set': name, **m})
    df = pd.DataFrame(records).set_index('set')

    pretty_print(df, "ALL STRATEGIES")

    df_filtered = df[
        (df['profit_factor'] > 1.0) &
        (df['max_drawdown'] > -0.15 * total_capital) &
        (df['total_trades'] >= 10)
    ]
    pretty_print(df_filtered, "AFTER FILTERS")

    if df_filtered.empty:
        print("\nNo strategies passed filters; ranking all of them instead.")
        df_filtered = df.copy()

    df_filtered['sharpe_rank'] = df_filtered['sharpe_ratio'].rank(pct=True)
    df_filtered['pf_rank']     = df_filtered['profit_factor'].rank(pct=True)
    df_filtered['dd_rank']     = 1 - df_filtered['max_drawdown'].abs().rank(pct=True)

    w1, w2, w3 = 0.5, 0.3, 0.2
    df_filtered['composite_score'] = (
        w1 * df_filtered['sharpe_rank']
      + w2 * df_filtered['pf_rank']
      + w3 * df_filtered['dd_rank']
    )

    ranked = df_filtered.sort_values('composite_score', ascending=False)
    pretty_print(ranked[['composite_score', 'total_trades','sharpe_ratio', 'profit_factor', 'max_drawdown']], 
# Set_85            0.2910             5       -0.3929         0.3742   -7,331.4845
# Set_119           0.2799             7       -0.4277         0.2276   -4,032.9724
# Set_34            0.2750             5       -0.2375         0.5183  -24,617.0843
# Set_94            0.2743             5       -0.2646         0.5308  -19,933.5694
# Set_131           0.2604             5       -0.2839         0.4970  -19,232.2148
# Set_96            0.2556             5       -0.4180         0.3309   -9,824.6433
# Set_15            0.2472             5       -0.2894         0.4207  -16,230.7267
# Set_20            0.2361             9       -0.5328         0.2679   -6,433.6024
# Set_76            0.2354             5       -0.4375         0.3152  -10,559.0651
# Set_73            0.2194             7       -0.4624         0.2110   -9,504.4193
# Set_3             0.2160             9       -0.4765         0.2888  -10,951.0777
# Set_63            0.2160             5       -0.2858         0.4737  -36,596.7671
# Set_107           0.2146             7       -0.2845         0.4497  -36,264.4095
# Set_124           0.2125             5       -0.4637         0.3088  -11,769.8873
# Set_17            0.2097             5       -0.4000         0.3291  -17,215.1247
# Set_139           0.2021             5       -0.3937         0.3619  -21,778.4454
# Set_77            0.1972             5       -0.5355         0.2639  -10,668.3582
# Set_43            0.1924             5       -0.3849         0.4119  -34,812.4511
# Set_83            0.1903             7       -1.0764         0.1165   -4,284.7818
# Set_93            0.1854             7       -0.4941         0.2695  -14,001.4895
# Set_132           0.1750             5       -0.4214         0.3452  -31,100.8408
# Set_141           0.1556             5       -0.5125         0.2984  -20,861.7848
# Set_103           0.1444             5       -0.7047         0.0228  -10,976.0773
# Set_104           0.1368             5       -0.5378         0.2397  -19,619.4893
# Set_127           0.1271             7       -0.7637         0.2104  -15,445.8113
# Set_137           0.1188             7       -1.2130         0.0000   -9,392.5168
# Set_97            0.1174             7       -0.5958         0.2586  -30,126.0616
# Set_115           0.1049             5       -0.6211         0.2093  -30,076.0271
# Set_78            0.1007             5       -0.6450         0.1898  -29,778.9648
# Set_95            0.1000             5       -0.8630         0.0567  -16,484.0980
# Set_98            0.0868             7       -0.6686         0.1341  -32,873.1885
# Set_33            0.0653             5       -0.8115         0.0908  -32,981.2207
# Set_36            0.0646             5       -0.7583         0.1044  -49,187.7256
# Set_125           0.0549             5       -1.1674         0.0277  -27,802.9031
# Set_58            0.0528             5       -1.2326         0.0000  -19,448.4089
# Set_72            0.0444             5       -1.2994         0.0034  -23,252.9767
# Set_42            0.0431             5       -0.9493         0.0000  -32,546.5118
# Set_7             0.0368             5       -0.8857         0.0000  -37,683.7968
# Set_67            0.0236             5       -1.5131         0.0000  -32,244.2999

# %%
ranked_df[['composite_score', 'total_trades','sharpe_ratio', 'profit_factor', 'max_drawdown']].head()
# Out:
#          composite_score  total_trades  sharpe_ratio  profit_factor  \
# set
# Set_24          0.991667             5      2.420938            inf
# Set_68          0.988194             5      2.288251            inf
# Set_133         0.984722             5      2.008714            inf
# Set_52          0.970833             5      1.320488     197.151107
# Set_142         0.961111             5      1.003541      11.259567
#
#          max_drawdown
# set
# Set_24       0.000000
# Set_68       0.000000
# Set_133      0.000000
# Set_52    -284.903258
# Set_142      0.000000
